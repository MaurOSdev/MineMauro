# %% [markdown]
# ┌─────────────────────────────────┐
# │  K E R N E L   S E R V E R      │
# │  [Status: Online] [RAM: 8GB]    │
# └─────────────────────────────────┘
#
#                                                      corre minecraft en google colab!

# %%
#el inicio - by mauro
import os
import time
from google.colab import drive

drive.mount('/content/drive')

# !ln -sf "/content/drive/My Drive/Minecraft-server" /content/mcserver

os.environ["JAVA_HOME"] = "/opt/jdk-mc"
os.environ["PATH"] = "/opt/jdk-mc/bin:" + os.environ["PATH"]
os.chdir("/content/mcserver")
print("directorio creado:", os.getcwd())

# !mkdir -p /root/.config/playit_gg
if os.path.exists("/content/mcserver/playit.toml"):
    # !cp /content/mcserver/playit.toml /root/.config/playit_gg/playit.toml

if not os.path.exists("/content/mcserver/playit"):
    # !wget -q -O /content/mcserver/playit "https://github.com/playit-cloud/playit-agent/releases/download/v0.17.1/playit-linux-amd64"
    # !chmod +x /content/mcserver/playit

props_path = "/content/mcserver/server.properties"
if os.path.exists(props_path):
    with open(props_path, "r") as f:
        props = f.read()
    props = props.replace("online-mode=true", "online-mode=false")
    with open(props_path, "w") as f:
        f.write(props)
else:
    with open(props_path, "w") as f:
        f.write("online-mode=false\nserver-port=25565\n")

# 7. EULA
with open("/content/mcserver/eula.txt", "w") as f:
    f.write("eula=true\n")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 📁 Directorio: /content/drive/My Drive/Minecraft-server
# ⚠️  No hay config guardada, necesitas hacer claim primero
# ✅ online-mode=false aplicado
#
# ✅ Setup listo, corre la celda 2

# %% [markdown]
# #EL SCRIPT PRINCIPAL
#
# este codigo tiene que ser activado despues de activar el script 1 este se encarga de los sistemas y todo eso

# %%
import os
import time

os.environ["JAVA_HOME"] = "/opt/jdk-mc"
os.environ["PATH"] = "/opt/jdk-mc/bin:" + os.environ["PATH"]
os.chdir("/content/mcserver")

# !pkill -f playit 2>/dev/null || true
time.sleep(2)

print("cargando playit")
get_ipython().system_raw('/content/mcserver/playit -s start > /tmp/playit_log.txt 2>&1 &')

time.sleep(15)
# !cat /tmp/playit_log.txt

# !java -Xmx8G -Xms8G -jar server.jar nogui
# Out:
# ^C
# cargando playit
# 2026-04-21T04:30:38.260554Z  INFO playit_cli::playit_secret: loading secret file_path=/content/mcserver/.playit-secret
# 2026-04-21T04:30:38.279226Z  INFO playit_cli::ui: checking if secret key is valid
# 2026-04-21T04:30:39.391106Z  INFO playit_cli::ui: secret key valid, agent has 1 tunnels
# 2026-04-21T04:30:44.492734Z  INFO playit_cli::ui: starting up tunnel connection
# 2026-04-21T04:30:44.598029Z  INFO playit_agent_core::agent_control::address_selector: trying to establish tunnel connection addr=[2602:fbaf:814:1::1]:5525
# 2026-04-21T04:30:44.598099Z ERROR playit_agent_core::agent_control::address_selector: failed to send initial ping error=Os { code: 101, kind: NetworkUnreachable, message: "Network unreachable" } addr=[2602:fbaf:814:1::1]:5525
# 2026-04-21T04:30:44.598115Z ERROR playit_agent_core::agent_control::address_selector: failed to ping tunnel server
# 2026-04-21T04:30:44.598118Z  INFO playit_agent_core::agent_control::address_selector: trying to establish tunnel connection addr=69.9.180.1:5525
# 2026-04-21T04:30:44.620032Z  INFO playit_agent_core::agent_control::address_selector: got initial pong from tunnel server pong=Pong { request_now: 1776745844598, server_now: 1776745844614, server_id: 1, data_center_id: 46, client_addr: 34.122.197.150:50622, tunnel_addr: 69.9.180.1:5525, session_expire_at: None }
# 2026-04-21T04:30:44.710778Z  INFO playit_agent_core::agent_control::connected_control: register queued, waiting 1s
# 2026-04-21T04:30:45.735270Z  INFO playit_cli::autorun: tunnel running
# 2026-04-21T04:30:45.735426Z  WARN playit_agent_core::agent_control::maintained_control: session expired reason=SessionNotSetup
# 2026-04-21T04:30:45.844551Z  INFO playit_agent_core::agent_control::established_control: authenticate control last_pong=Pong { request_now: 1776745844598, server_now: 1776745844614, server_id: 1, data_center_id: 46, client_addr: 34.122.197.150:50622, tunnel_addr: 69.9.180.1:5525, session_expire_at: None }
# 2026-04-21T04:30:45.844690Z  INFO playit_agent_core::agent_control::maintained_control: send KeepAlive time_till_expire=298861
# 2026-04-21T04:30:45.866022Z  INFO playit_agent_core::agent_control::established_control: agent registered details=AgentRegistered { id: AgentSessionId { session_id: 27896, account_id: 2237761, agent_id: 6050942 }, expires_at: 1776746144705 }
# 2026-04-21T04:30:46.875850Z  WARN playit_agent_core::agent_control::maintained_control: session expired reason=SessionNotSetup
# 2026-04-21T04:30:46.990273Z  INFO playit_agent_core::agent_control::established_control: authenticate control last_pong=Pong { request_now: 1776745845844, server_now: 1776745845860, server_id: 1, data_center_id: 46, client_addr: 34.122.197.150:50622, tunnel_addr: 69.9.180.1:5525, session_expire_at: Some(1776746144705) }
# 2026-04-21T04:30:48.799936Z  INFO playit_cli::ui: playit (v0.17.1): 1776745848799 tunnel running, 1 tunnels registered
# 2026-04-21T04:30:49.058092Z  INFO playit_agent_core::playit_agent: udp channel requires auth, sent auth request
# 2026-04-21T04:30:49.079358Z  INFO playit_agent_core::playit_agent: udp session details received
# 2026-04-21T04:30:51.866969Z  INFO playit_cli::ui: playit (v0.17.1): 1776745851866 tunnel running, 1 tunnels registered
# [0.002s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# [0.002s][warning][os,container] Cgroup cpu controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# Starting net.minecraft.server.Main
# WARNING: A restricted method in java.lang.System has been called
# WARNING: java.lang.System::load has been called by com.sun.jna.Native in an unnamed module (file:/content/drive/My%20Drive/Minecraft-server/libraries/net/java/dev/jna/jna/5.17.0/jna-5.17.0.jar)
# WARNING: Use --enable-native-access=ALL-UNNAMED to avoid a warning for callers in this module
# WARNING: Restricted methods will be blocked in a future release unless native access is enabled
#
# WARNING: A terminally deprecated method in sun.misc.Unsafe has been called
# WARNING: sun.misc.Unsafe::objectFieldOffset has been called by org.joml.MemUtil$MemUtilUnsafe (file:/content/drive/My%20Drive/Minecraft-server/libraries/org/joml/joml/1.10.8/joml-1.10.8.jar)
# WARNING: Please consider reporting this to the maintainers of class org.joml.MemUtil$MemUtilUnsafe
# WARNING: sun.misc.Unsafe::objectFieldOffset will be removed in a future release
# [04:31:09] [ServerMain/INFO]: Environment: Environment[sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, profilesHost=https://api.mojang.com, name=PROD]
# [04:31:15] [ServerMain/INFO]: Loaded 1515 recipes
# [04:31:15] [ServerMain/INFO]: Loaded 1617 advancements
# [04:31:15] [Server thread/INFO]: Starting minecraft server version 26.1.1
# [04:31:15] [Server thread/INFO]: Loading properties
# [04:31:15] [Server thread/INFO]: Default game type: SURVIVAL
# [04:31:15] [Server thread/INFO]: Generating keypair
# [04:31:16] [Server thread/INFO]: Starting Minecraft server on *:25565
# [04:31:17] [Server thread/WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [04:31:17] [Server thread/WARN]: The server will make no attempt to authenticate usernames. Beware.
# [04:31:17] [Server thread/WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [04:31:17] [Server thread/WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [04:31:17] [Server thread/INFO]: Preparing level "world"
# [04:31:18] [Server thread/INFO]: Loading 0 persistent chunks...
# [04:31:18] [Server thread/INFO]: Preparing spawn area: 100%
# [04:31:18] [Server thread/INFO]: Time elapsed: 38 ms
# [04:31:18] [Server thread/INFO]: Done (1.527s)! For help, type "help"
# [04:31:18] [Server thread/INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:overworld
# [04:31:18] [Server thread/INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:the_end
# [04:31:18] [Server thread/INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:the_nether
# [04:31:18] [Server thread/INFO]: ThreadedAnvilChunkStorage (world): All chunks are saved
# [04:31:18] [Server thread/INFO]: ThreadedAnvilChunkStorage (DIM1): All chunks are saved
# [04:31:18] [Server thread/INFO]: ThreadedAnvilChunkStorage (DIM-1): All chunks are saved
# [04:31:18] [Server thread/INFO]: ThreadedAnvilChunkStorage: All dimensions are saved
# [04:32:18] [Server thread/INFO]: Server empty for 60 seconds, pausing
# [04:38:23] [Server thread/INFO]: KernelKid[/127.247.113.84:38931] logged in with entity id 44 at (-5.1379504109881, 63.0, 94.37177367386961)
# [04:38:24] [Server thread/INFO]: KernelKid joined the game
# [04:41:05] [Server thread/INFO]: [Not Secure] <KernelKid> ç
# [04:44:41] [Server thread/INFO]: KernelKid was speared by Zombie
# [04:45:00] [Server thread/INFO]: KernelKid was speared by Zombie
# [04:46:18] [Server thread/INFO]: KernelKid was speared by Zombie
# [04:56:57] [Server thread/INFO]: [Not Secure] <KernelKid> Hotline!
# [04:58:04] [Server thread/INFO]: [Not Secure] <KernelKid> Hotline! Hung up and put it on hold! (Old)(Hotline!)My line is getting cold! (O-o-old)(Hotline!)Hung up and put it on hold! (O-o-old)(Hotline!)(Oh, uh, I'll try again though)
# [04:58:52] [Server thread/INFO]: [Not Secure] <KernelKid> mi pansususun
# [04:59:03] [Server thread/INFO]: [Not Secure] <KernelKid> mi pan akasusu ñan ñam ñam
# [04:59:11] [Server thread/INFO]: [Not Secure] <KernelKid> mi paaaaaaaaaaaaan susususn
